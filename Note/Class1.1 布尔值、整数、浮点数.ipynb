# %% [markdown]
# # Class1.1 布尔值、整数、浮点数
# 本课**无作业**

# %%
bool_1 = True
int_1 = 1
float_1 = 1.2

print(bool_1, int_1, float_1)  # 打印bool_1, int_1, float_1，中间空格分隔开
print(bool_1 + int_1 + float_1)  # bool_1, int_1, float_1，中间无空格分隔开
# Out:
# True 1 1.2
# 3.2
